# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
from pprint import pprint
import csv
# Google API Key
from config import key

# %%
url = "https://na1.api.riotgames.com/lol/match/v4/matches/"
api_f= "api_key="

# %%
#csv files to work through adjust the file path to needs
#this is match data
file = "data/matchinfo.csv"

#this is a list of game ids to get data from
qfile = "data/queue.csv"

#jsonifying the api data
#reading in the game ids
queue = pd.read_csv(qfile, header = None)

#partic_data = response['participants']

#trying to create a loop to iterate through our gameids
#so that we can get more than just the one data set
queue_random = queue.sample(1)

#n_url = (url + "3019374593/?" + api_f + key)
#response = requests.get(n_url).json()

for index,row in queue_random.iterrows():
    n_url = (url + str(row[0]) + "/?"+ api_f + key) 
    response = requests.get(n_url).json()
    try:
        teamid.append(response["teams"][0]["teamid"])
        teamid2.append(response["teams"][1]["teamId"])
        
        print(teamid2)
    # Handle exceptions for a site that is not available in the API
    except:
        # Append null values - try appending None
        teamid.append(None)
        teamid2.append(None)
        pass

    
"""           

    # storing our numerical data based on a singular game
    # pulling specific frames from team data to graph etc.
    # Team id 100 tower kills / first tower kill / first inhibitor
    # dragon kills / baron kills
            oh_dict = {
                "teamid" : response["teams"][0]["teamId"],
                "oh_TowerKills" : response["teams"][0]["towerKills"],
                "oh_firstTower" : response["teams"][0]["firstTower"],
                "oh_firstInhibitor" : response["teams"][0]["firstInhibitor"],
                "oh_dragonKills" : response["teams"][0]["dragonKills"],
                "oh_firstBlood" : response["teams"][0]["firstBlood"],
                    }
    # Team id 200 tower kill data / first tower kill data / first inhibitor data
    # dragon kills / baron kills
            th_dict = {
                "teamid" : response["teams"][1]["teamId"],
                "th_towerKills" :  response["teams"][1]["towerKills"],
                "th_firstTowerKill" : response["teams"][1]["firstTower"],
                "th_firstInhibitor" : response["teams"][1]["firstInhibitor"],
                "th_dragonKills" : response["teams"][1]["dragonKills"],
                "th_first_blood" : response["teams"][1]["firstBlood"]
                        }
    # team id 100 dataframe
            oh_df = pd.DataFrame(oh_dict, index = [0])
    # team id 200 dataframe
            th_df = pd.DataFrame(th_dict, index = [0])

    #    pprint (response)
    """
# Out:
# '           \n\n    # storing our numerical data based on a singular game\n    # pulling specific frames from team data to graph etc.\n    # Team id 100 tower kills / first tower kill / first inhibitor\n    # dragon kills / baron kills\n            oh_dict = {\n                "teamid" : response["teams"][0]["teamId"],\n                "oh_TowerKills" : response["teams"][0]["towerKills"],\n                "oh_firstTower" : response["teams"][0]["firstTower"],\n                "oh_firstInhibitor" : response["teams"][0]["firstInhibitor"],\n                "oh_dragonKills" : response["teams"][0]["dragonKills"],\n                "oh_firstBlood" : response["teams"][0]["firstBlood"],\n                    }\n    # Team id 200 tower kill data / first tower kill data / first inhibitor data\n    # dragon kills / baron kills\n            th_dict = {\n                "teamid" : response["teams"][1]["teamId"],\n                "th_towerKills" :  response["teams"][1]["towerKills"],\n                "th_firstTowerKill" : response["teams"][1]["firstTower"],\n                "th_firstInhibitor" : response["teams"][1]["firstInhibitor"],\n                "th_dragonKills" : response["teams"][1]["dragonKills"],\n                "th_first_blood" : response["teams"][1]["firstBlood"]\n                        }\n    # team id 100 dataframe\n            oh_df = pd.DataFrame(oh_dict, index = [0])\n    # team id 200 dataframe\n            th_df = pd.DataFrame(th_dict, index = [0])\n\n    #    pprint (response)\n    '

# %%
pprint(response["teams"])
# Out:
# [{'bans': [{'championId': 122, 'pickTurn': 1},
#            {'championId': 223, 'pickTurn': 3},
#            {'championId': 142, 'pickTurn': 5}],
#   'baronKills': 0,
#   'dominionVictoryScore': 0,
#   'dragonKills': 0,
#   'firstBaron': False,
#   'firstBlood': True,
#   'firstDragon': False,
#   'firstInhibitor': True,
#   'firstRiftHerald': False,
#   'firstTower': True,
#   'inhibitorKills': 1,
#   'riftHeraldKills': 0,
#   'teamId': 100,
#   'towerKills': 5,
#   'vilemawKills': 0,
#   'win': 'Win'},
#  {'bans': [{'championId': 266, 'pickTurn': 2},
#            {'championId': 1, 'pickTurn': 4},
#            {'championId': 350, 'pickTurn': 6}],
#   'baronKills': 0,
#   'dominionVictoryScore': 0,
#   'dragonKills': 0,
#   'firstBaron': False,
#   'firstBlood': False,
#   'firstDragon': False,
#   'firstInhibitor': False,
#   'firstRiftHerald': False,
#   'firstTower': False,
#   'inhibitorKills': 0,
#   'riftHeraldKills': 0,
#   'teamId': 200,
#   'towerKills': 0,
#   'vilemawKills': 0,
#   'win': 'Fail'}]

# %%
partic_1_dict = {
        "player_Id" : partic_data[0]["participantId"],
        "hghtest_Tier" : partic_data[0]['highestAchievedSeasonTier'],
        "player_Assists" : partic_data[0]['stats']["assists"],
        "player_Deaths" : partic_data[0]['stats']["deaths"],
        "player_DoubleKills" : partic_data[0]['stats']["doubleKills"],
        "player_Kills" : partic_data[0]['stats']["kills"],
        "player_Lane" : partic_data[0]["timeline"]["lane"]
        "player_Gold" : partic_data[0]['stats']["goldEarned"],
        "player_Spent" : partic_data[0]['stats']["goldSpent"],
            }

# %%
#player data
pprint(partic_data)
# Out:
# [{'championId': 518,
#   'highestAchievedSeasonTier': 'GOLD',
#   'participantId': 1,
#   'spell1Id': 3,
#   'spell2Id': 4,
#   'stats': {'assists': 4,
#             'champLevel': 12,
#             'combatPlayerScore': 0,
#             'damageDealtToObjectives': 2917,
#             'damageDealtToTurrets': 2035,
#             'damageSelfMitigated': 4261,
#             'deaths': 1,
#             'doubleKills': 0,
#             'firstBloodAssist': False,
#             'firstBloodKill': False,
#             'firstInhibitorAssist': True,
#             'firstInhibitorKill': False,
#             'firstTowerAssist': True,
#             'firstTowerKill': False,
#             'goldEarned': 6807,
#             'goldSpent': 6025,
#             'inhibitorKills': 0,
#             'item0': 3098,
#             'item1': 3165,
#             'item2': 3111,
#             'item3': 3801,
#             'item4': 1004,
#             'item5': 2055,
#             'item6': 3364,
#             'killingSprees': 0,
#             'kills': 1,
#             'largestCriticalStrike': 0,
#             'largestKillingSpree': 0,
#             'largestMultiKill': 1,
#             'longestTimeSpentLiving': 1101,
#             'magicDamageDealt': 33366,
#             'magicDamageDealtToChampions': 7330,
#             'magicalDamageTaken': 3682,
#             'neutralMinionsKilled': 0,
#             'neutralMinionsKilledEnemyJungle': 0,
#             'neutralMinionsKilledTeamJungle': 0,
#             'objectivePlayerScore': 0,
#             'participantId': 1,
#             'pentaKills': 0,
#             'perk0': 8128,
#             'perk0Var1': 413,
#             'perk0Var2': 8,
#             'perk0Var3': 668,
#             'perk1': 8126,
#             'perk1Var1': 318,
#             'perk1Var2': 0,
#             'perk1Var3': 0,
#             'perk2': 8136,
#             'perk2Var1': 3,
#             'perk2Var2': 6,
#             'perk2Var3': 0,
#             'perk3': 8135,
#             'perk3Var1': 495,
#             'perk3Var2': 4,
#             'perk3Var3': 0,
#             'perk4': 8210,
#             'perk4Var1': 0,
#             'perk4Var2': 0,
#             'perk4Var3': 0,
#             'perk5': 8237,
#             'perk5Var1': 240,
#             'perk5Var2': 0,
#             'perk5Var3': 0,
#             'perkPrimaryStyle': 8100,
#             'perkSubStyle': 8200,
#             'physicalDamageDealt': 4800,
#             'physicalDamageDealtToChampions': 603,
#             'physicalDamageTaken': 6184,
#             'playerScore0': 0,
#             'playerScore1': 0,
#             'playerScore2': 0,
#             'playerScore3': 0,
#             'playerScore4': 0,
#             'playerScore5': 0,
#             'playerScore6': 0,
#             'playerScore7': 0,
#             'playerScore8': 0,
#             'playerScore9': 0,
#             'quadraKills': 0,
#             'sightWardsBoughtInGame': 0,
#             'statPerk0': 5008,
#             'statPerk1': 5008,
#             'statPerk2': 5001,
#             'timeCCingOthers': 24,
#             'totalDamageDealt': 38538,
#             'totalDamageDealtToChampions': 8169,
#             'totalDamageTaken': 9967,
#             'totalHeal': 1509,
#             'totalMinionsKilled': 50,
#             'totalPlayerScore': 0,
#             'totalScoreRank': 0,
#             'totalTimeCrowdControlDealt': 116,
#             'totalUnitsHealed': 1,
#             'tripleKills': 0,
#             'trueDamageDealt': 370,
#             'trueDamageDealtToChampions': 235,
#             'trueDamageTaken': 100,
#             'turretKills': 0,
#             'unrealKills': 0,
#             'visionScore': 26,
#             'visionWardsBoughtInGame': 2,
#             'wardsKilled': 3,
#             'wardsPlaced': 10,
#             'win': True},
#   'teamId': 100,
#   'timeline': {'creepsPerMinDeltas': {'0-10': 0.7999999999999999, '10-20': 3.2},
#                'csDiffPerMinDeltas': {'0-10': 0.3500000000000001,
#                                       '10-20': 1.1000000000000005},
#                'damageTakenDiffPerMinDeltas': {'0-10': -59.20000000000002,
#                                                '10-20': -72.00000000000006},
#                'damageTakenPerMinDeltas': {'0-10': 136.8, '10-20': 604.5},
#                'goldPerMinDeltas': {'0-10': 182.70000000000002, '10-20': 272.5},
#                'lane': 'BOTTOM',
#                'participantId': 1,
#                'role': 'DUO_SUPPORT',
#                'xpDiffPerMinDeltas': {'0-10': 28.700000000000017,
#                                       '10-20': 136.09999999999997},
#                'xpPerMinDeltas': {'0-10': 306.1, '10-20': 380.79999999999995}}},
#  {'championId': 85,
#   'highestAchievedSeasonTier': 'GOLD',
#   'participantId': 2,
#   'spell1Id': 4,
#   'spell2Id': 14,
#   'stats': {'assists': 5,
#             'champLevel': 14,
#             'combatPlayerScore': 0,
#             'damageDealtToObjectives': 9027,
#             'damageDealtToTurrets': 8396,
#             'damageSelfMitigated': 6701,
#             'deaths': 1,
#             'doubleKills': 1,
#             'firstBloodAssist': False,
#             'firstBloodKill': False,
#             'firstInhibitorAssist': False,
#             'firstInhibitorKill': True,
#             'firstTowerAssist': False,
#             'firstTowerKill': True,
#             'goldEarned': 12066,
#             'goldSpent': 11025,
#             'inhibitorKills': 1,
#             'item0': 3157,
#             'item1': 3152,
#             'item2': 3907,
#             'item3': 1055,
#             'item4': 3117,
#             'item5': 1058,
#             'item6': 3340,
#             'killingSprees': 2,
#             'kills': 12,
#             'largestCriticalStrike': 0,
#             'largestKillingSpree': 10,
#             'largestMultiKill': 2,
#             'longestTimeSpentLiving': 874,
#             'magicDamageDealt': 87765,
#             'magicDamageDealtToChampions': 18060,
#             'magicalDamageTaken': 5548,
#             'neutralMinionsKilled': 8,
#             'neutralMinionsKilledEnemyJungle': 0,
#             'neutralMinionsKilledTeamJungle': 4,
#             'objectivePlayerScore': 0,
#             'participantId': 2,
#             'pentaKills': 0,
#             'perk0': 8112,
#             'perk0Var1': 1324,
#             'perk0Var2': 0,
#             'perk0Var3': 0,
#             'perk1': 8143,
#             'perk1Var1': 393,
#             'perk1Var2': 0,
#             'perk1Var3': 0,
#             'perk2': 8138,
#             'perk2Var1': 30,
#             'perk2Var2': 0,
#             'perk2Var3': 0,
#             'perk3': 8106,
#             'perk3Var1': 5,
#             'perk3Var2': 0,
#             'perk3Var3': 0,
#             'perk4': 8237,
#             'perk4Var1': 374,
#             'perk4Var2': 0,
#             'perk4Var3': 0,
#             'perk5': 8233,
#             'perk5Var1': 13,
#             'perk5Var2': 40,
#             'perk5Var3': 0,
#             'perkPrimaryStyle': 8100,
#             'perkSubStyle': 8200,
#             'physicalDamageDealt': 19859,
#             'physicalDamageDealtToChampions': 1839,
#             'physicalDamageTaken': 6012,
#             'playerScore0': 0,
#             'playerScore1': 0,
#             'playerScore2': 0,
#             'playerScore3': 0,
#             'playerScore4': 0,
#             'playerScore5': 0,
#             'playerScore6': 0,
#             'playerScore7': 0,
#             'playerScore8': 0,
#             'playerScore9': 0,
#             'quadraKills': 0,
#             'sightWardsBoughtInGame': 0,
#             'statPerk0': 5008,
#             'statPerk1': 5008,
#             'statPerk2': 5001,
#             'timeCCingOthers': 18,
#             'totalDamageDealt': 111975,
#             'totalDamageDealtToChampions': 20406,
#             'totalDamageTaken': 11822,
#             'totalHeal': 1501,
#             'totalMinionsKilled': 145,
#             'totalPlayerScore': 0,
#             'totalScoreRank': 0,
#             'totalTimeCrowdControlDealt': 49,
#             'totalUnitsHealed': 1,
#             'tripleKills': 0,
#             'trueDamageDealt': 4350,
#             'trueDamageDealtToChampions': 506,
#             'trueDamageTaken': 262,
#             'turretKills': 3,
#             'unrealKills': 0,
#             'visionScore': 12,
#             'visionWardsBoughtInGame': 1,
#             'wardsKilled': 1,
#             'wardsPlaced': 7,
#             'win': True},
#   'teamId': 100,
#   'timeline': {'creepsPerMinDeltas': {'0-10': 6.4, '10-20': 5.5},
#                'csDiffPerMinDeltas': {'0-10': 0.20000000000000018,
#                                       '10-20': -0.2000000000000004},
#                'damageTakenDiffPerMinDeltas': {'0-10': -51.39999999999999,
#                                                '10-20': 21.099999999999994},
#                'damageTakenPerMinDeltas': {'0-10': 272, '10-20': 499.7},
#                'goldPerMinDeltas': {'0-10': 286.5, '10-20': 583.8},
#                'lane': 'MIDDLE',
#                'participantId': 2,
#                'role': 'SOLO',
#                'xpDiffPerMinDeltas': {'0-10': 17.49999999999997,
#                                       '10-20': 211.09999999999997},
#                'xpPerMinDeltas': {'0-10': 460.4, '10-20': 578.4}}},
#  {'championId': 21,
#   'highestAchievedSeasonTier': 'GOLD',
#   'participantId': 3,
#   'spell1Id': 4,
#   'spell2Id': 7,
#   'stats': {'assists': 9,
#             'champLevel': 13,
#             'combatPlayerScore': 0,
#             'damageDealtToObjectives': 15179,
#             'damageDealtToTurrets': 12462,
#             'damageSelfMitigated': 3682,
#             'deaths': 2,
#             'doubleKills': 0,
#             'firstBloodAssist': False,
#             'firstBloodKill': False,
#             'firstInhibitorAssist': False,
#             'firstInhibitorKill': False,
#             'firstTowerAssist': True,
#             'firstTowerKill': False,
#             'goldEarned': 9921,
#             'goldSpent': 8525,
#             'inhibitorKills': 0,
#             'item0': 1055,
#             'item1': 3508,
#             'item2': 3142,
#             'item3': 3006,
#             'item4': 1036,
#             'item5': 1036,
#             'item6': 3340,
#             'killingSprees': 0,
#             'kills': 0,
#             'largestCriticalStrike': 687,
#             'largestKillingSpree': 0,
#             'largestMultiKill': 0,
#             'longestTimeSpentLiving': 983,
#             'magicDamageDealt': 824,
#             'magicDamageDealtToChampions': 459,
#             'magicalDamageTaken': 4000,
#             'neutralMinionsKilled': 12,
#             'neutralMinionsKilledEnemyJungle': 4,
#             'neutralMinionsKilledTeamJungle': 0,
#             'objectivePlayerScore': 0,
#             'participantId': 3,
#             'pentaKills': 0,
#             'perk0': 8021,
#             'perk0Var1': 628,
#             'perk0Var2': 0,
#             'perk0Var3': 0,
#             'perk1': 9111,
#             'perk1Var1': 291,
#             'perk1Var2': 180,
#             'perk1Var3': 0,
#             'perk2': 9104,
#             'perk2Var1': 17,
#             'perk2Var2': 40,
#             'perk2Var3': 0,
#             'perk3': 8017,
#             'perk3Var1': 109,
#             'perk3Var2': 0,
#             'perk3Var3': 0,
#             'perk4': 8138,
#             'perk4Var1': 10,
#             'perk4Var2': 0,
#             'perk4Var3': 0,
#             'perk5': 8139,
#             'perk5Var1': 548,
#             'perk5Var2': 0,
#             'perk5Var3': 0,
#             'perkPrimaryStyle': 8000,
#             'perkSubStyle': 8100,
#             'physicalDamageDealt': 105401,
#             'physicalDamageDealtToChampions': 5906,
#             'physicalDamageTaken': 5176,
#             'playerScore0': 0,
#             'playerScore1': 0,
#             'playerScore2': 0,
#             'playerScore3': 0,
#             'playerScore4': 0,
#             'playerScore5': 0,
#             'playerScore6': 0,
#             'playerScore7': 0,
#             'playerScore8': 0,
#             'playerScore9': 0,
#             'quadraKills': 0,
#             'sightWardsBoughtInGame': 0,
#             'statPerk0': 5005,
#             'statPerk1': 5008,
#             'statPerk2': 5001,
#             'timeCCingOthers': 3,
#             'totalDamageDealt': 112180,
#             'totalDamageDealtToChampions': 6438,
#             'totalDamageTaken': 9609,
#             'totalHeal': 2243,
#             'totalMinionsKilled': 180,
#             'totalPlayerScore': 0,
#             'totalScoreRank': 0,
#             'totalTimeCrowdControlDealt': 42,
#             'totalUnitsHealed': 2,
#             'tripleKills': 0,
#             'trueDamageDealt': 5954,
#             'trueDamageDealtToChampions': 72,
#             'trueDamageTaken': 432,
#             'turretKills': 3,
#             'unrealKills': 0,
#             'visionScore': 18,
#             'visionWardsBoughtInGame': 1,
#             'wardsKilled': 0,
#             'wardsPlaced': 6,
#             'win': True},
#   'teamId': 100,
#   'timeline': {'creepsPerMinDeltas': {'0-10': 7, '10-20': 7.699999999999999},
#                'csDiffPerMinDeltas': {'0-10': 0.3500000000000001,
#                                       '10-20': 1.1000000000000005},
#                'damageTakenDiffPerMinDeltas': {'0-10': -59.20000000000002,
#                                                '10-20': -72.00000000000006},
#                'damageTakenPerMinDeltas': {'0-10': 152.1, '10-20': 449.9},
#                'goldPerMinDeltas': {'0-10': 258.6, '10-20': 464.7},
#                'lane': 'BOTTOM',
#                'participantId': 3,
#                'role': 'DUO_CARRY',
#                'xpDiffPerMinDeltas': {'0-10': 28.700000000000017,
#                                       '10-20': 136.09999999999997},
#                'xpPerMinDeltas': {'0-10': 326, '10-20': 528}}},
#  {'championId': 421,
#   'highestAchievedSeasonTier': 'SILVER',
#   'participantId': 4,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'assists': 9,
#             'champLevel': 13,
#             'combatPlayerScore': 0,
#             'damageDealtToObjectives': 20791,
#             'damageDealtToTurrets': 1483,
#             'damageSelfMitigated': 10688,
#             'deaths': 3,
#             'doubleKills': 1,
#             'firstBloodAssist': False,
#             'firstBloodKill': True,
#             'firstInhibitorAssist': True,
#             'firstInhibitorKill': False,
#             'firstTowerAssist': False,
#             'firstTowerKill': False,
#             'goldEarned': 9810,
#             'goldSpent': 8550,
#             'inhibitorKills': 0,
#             'item0': 1400,
#             'item1': 2031,
#             'item2': 3748,
#             'item3': 3047,
#             'item4': 3044,
#             'item5': 0,
#             'item6': 3364,
#             'killingSprees': 1,
#             'kills': 5,
#             'largestCriticalStrike': 0,
#             'largestKillingSpree': 3,
#             'largestMultiKill': 2,
#             'longestTimeSpentLiving': 434,
#             'magicDamageDealt': 3419,
#             'magicDamageDealtToChampions': 0,
#             'magicalDamageTaken': 4789,
#             'neutralMinionsKilled': 106,
#             'neutralMinionsKilledEnemyJungle': 8,
#             'neutralMinionsKilledTeamJungle': 70,
#             'objectivePlayerScore': 0,
#             'participantId': 4,
#             'pentaKills': 0,
#             'perk0': 8010,
#             'perk0Var1': 288,
#             'perk0Var2': 110,
#             'perk0Var3': 411,
#             'perk1': 9111,
#             'perk1Var1': 776,
#             'perk1Var2': 280,
#             'perk1Var3': 0,
#             'perk2': 9105,
#             'perk2Var1': 14,
#             'perk2Var2': 0,
#             'perk2Var3': 0,
#             'perk3': 8014,
#             'perk3Var1': 135,
#             'perk3Var2': 0,
#             'perk3Var3': 0,
#             'perk4': 8304,
#             'perk4Var1': 8,
#             'perk4Var2': 3,
#             'perk4Var3': 0,
#             'perk5': 8347,
#             'perk5Var1': 0,
#             'perk5Var2': 0,
#             'perk5Var3': 0,
#             'perkPrimaryStyle': 8000,
#             'perkSubStyle': 8300,
#             'physicalDamageDealt': 105200,
#             'physicalDamageDealtToChampions': 8511,
#             'physicalDamageTaken': 14458,
#             'playerScore0': 0,
#             'playerScore1': 0,
#             'playerScore2': 0,
#             'playerScore3': 0,
#             'playerScore4': 0,
#             'playerScore5': 0,
#             'playerScore6': 0,
#             'playerScore7': 0,
#             'playerScore8': 0,
#             'playerScore9': 0,
#             'quadraKills': 0,
#             'sightWardsBoughtInGame': 0,
#             'statPerk0': 5005,
#             'statPerk1': 5008,
#             'statPerk2': 5002,
#             'timeCCingOthers': 19,
#             'totalDamageDealt': 125182,
#             'totalDamageDealtToChampions': 11020,
#             'totalDamageTaken': 19881,
#             'totalHeal': 11147,
#             'totalMinionsKilled': 20,
#             'totalPlayerScore': 0,
#             'totalScoreRank': 0,
#             'totalTimeCrowdControlDealt': 233,
#             'totalUnitsHealed': 1,
#             'tripleKills': 0,
#             'trueDamageDealt': 16561,
#             'trueDamageDealtToChampions': 2508,
#             'trueDamageTaken': 634,
#             'turretKills': 1,
#             'unrealKills': 0,
#             'visionScore': 20,
#             'visionWardsBoughtInGame': 3,
#             'wardsKilled': 2,
#             'wardsPlaced': 6,
#             'win': True},
#   'teamId': 100,
#   'timeline': {'creepsPerMinDeltas': {'0-10': 0.1, '10-20': 1.3},
#                'csDiffPerMinDeltas': {'0-10': -0.1,
#                                       '10-20': 0.9999999999999999},
#                'damageTakenDiffPerMinDeltas': {'0-10': -73.79999999999995,
#                                                '10-20': 83.19999999999999},
#                'damageTakenPerMinDeltas': {'0-10': 554, '10-20': 1131.5},
#                'goldPerMinDeltas': {'0-10': 293.6, '10-20': 428.3},
#                'lane': 'JUNGLE',
#                'participantId': 4,
#                'role': 'NONE',
#                'xpDiffPerMinDeltas': {'0-10': -28.19999999999999,
#                                       '10-20': 154.8},
#                'xpPerMinDeltas': {'0-10': 306.9, '10-20': 554.3}}},
#  {'championId': 6,
#   'highestAchievedSeasonTier': 'SILVER',
#   'participantId': 5,
#   'spell1Id': 14,
#   'spell2Id': 4,
#   'stats': {'assists': 7,
#             'champLevel': 14,
#             'combatPlayerScore': 0,
#             'damageDealtToObjectives': 4064,
#             'damageDealtToTurrets': 3283,
#             'damageSelfMitigated': 12354,
#             'deaths': 0,
#             'doubleKills': 0,
#             'firstBloodAssist': False,
#             'firstBloodKill': False,
#             'firstInhibitorAssist': True,
#             'firstInhibitorKill': False,
#             'firstTowerAssist': False,
#             'firstTowerKill': False,
#             'goldEarned': 9453,
#             'goldSpent': 8450,
#             'inhibitorKills': 0,
#             'item0': 3022,
#             'item1': 3071,
#             'item2': 3111,
#             'item3': 2138,
#             'item4': 0,
#             'item5': 0,
#             'item6': 3340,
#             'killingSprees': 1,
#             'kills': 7,
#             'largestCriticalStrike': 0,
#             'largestKillingSpree': 7,
#             'largestMultiKill': 1,
#             'longestTimeSpentLiving': 0,
#             'magicDamageDealt': 0,
#             'magicDamageDealtToChampions': 0,
#             'magicalDamageTaken': 5477,
#             'neutralMinionsKilled': 4,
#             'neutralMinionsKilledEnemyJungle': 4,
#             'neutralMinionsKilledTeamJungle': 0,
#             'objectivePlayerScore': 0,
#             'participantId': 5,
#             'pentaKills': 0,
#             'perk0': 8010,
#             'perk0Var1': 252,
#             'perk0Var2': 103,
#             'perk0Var3': 308,
#             'perk1': 9111,
#             'perk1Var1': 1064,
#             'perk1Var2': 280,
#             'perk1Var3': 0,
#             'perk2': 9104,
#             'perk2Var1': 17,
#             'perk2Var2': 40,
#             'perk2Var3': 0,
#             'perk3': 8014,
#             'perk3Var1': 227,
#             'perk3Var2': 0,
#             'perk3Var3': 0,
#             'perk4': 8446,
#             'perk4Var1': 1211,
#             'perk4Var2': 0,
#             'perk4Var3': 0,
#             'perk5': 8473,
#             'perk5Var1': 279,
#             'perk5Var2': 0,
#             'perk5Var3': 0,
#             'perkPrimaryStyle': 8000,
#             'perkSubStyle': 8400,
#             'physicalDamageDealt': 75997,
#             'physicalDamageDealtToChampions': 7428,
#             'physicalDamageTaken': 5251,
#             'playerScore0': 0,
#             'playerScore1': 0,
#             'playerScore2': 0,
#             'playerScore3': 0,
#             'playerScore4': 0,
#             'playerScore5': 0,
#             'playerScore6': 0,
#             'playerScore7': 0,
#             'playerScore8': 0,
#             'playerScore9': 0,
#             'quadraKills': 0,
#             'sightWardsBoughtInGame': 0,
#             'statPerk0': 5005,
#             'statPerk1': 5003,
#             'statPerk2': 5003,
#             'timeCCingOthers': 17,
#             'totalDamageDealt': 84929,
#             'totalDamageDealtToChampions': 8293,
#             'totalDamageTaken': 10729,
#             'totalHeal': 1736,
#             'totalMinionsKilled': 123,
#             'totalPlayerScore': 0,
#             'totalScoreRank': 0,
#             'totalTimeCrowdControlDealt': 134,
#             'totalUnitsHealed': 1,
#             'tripleKills': 0,
#             'trueDamageDealt': 8931,
#             'trueDamageDealtToChampions': 864,
#             'trueDamageTaken': 0,
#             'turretKills': 0,
#             'unrealKills': 0,
#             'visionScore': 13,
#             'visionWardsBoughtInGame': 0,
#             'wardsKilled': 2,
#             'wardsPlaced': 7,
#             'win': True},
#   'teamId': 100,
#   'timeline': {'creepsPerMinDeltas': {'0-10': 4.9, '10-20': 5.6},
#                'csDiffPerMinDeltas': {'0-10': -2.1999999999999997,
#                                       '10-20': -0.5000000000000004},
#                'damageTakenDiffPerMinDeltas': {'0-10': -51.8,
#                                                '10-20': -296.19999999999993},
#                'damageTakenPerMinDeltas': {'0-10': 219.39999999999998,
#                                            '10-20': 563.5},
#                'goldPerMinDeltas': {'0-10': 216.2, '10-20': 408.4},
#                'lane': 'TOP',
#                'participantId': 5,
#                'role': 'SOLO',
#                'xpDiffPerMinDeltas': {'0-10': -22.799999999999983,
#                                       '10-20': 49.80000000000001},
#                'xpPerMinDeltas': {'0-10': 417.3, '10-20': 545.8}}},
#  {'championId': 8,
#   'highestAchievedSeasonTier': 'SILVER',
#   'participantId': 6,
#   'spell1Id': 14,
#   'spell2Id': 4,
#   'stats': {'assists': 3,
#             'champLevel': 13,
#             'combatPlayerScore': 0,
#             'damageDealtToObjectives': 2209,
#             'damageDealtToTurrets': 2209,
#             'damageSelfMitigated': 6873,
#             'deaths': 5,
#             'doubleKills': 0,
#             'firstBloodAssist': False,
#             'firstBloodKill': False,
#             'firstInhibitorAssist': False,
#             'firstInhibitorKill': False,
#             'firstTowerAssist': False,
#             'firstTowerKill': False,
#             'goldEarned': 7631,
#             'goldSpent': 7150,
#             'inhibitorKills': 0,
#             'item0': 1026,
#             'item1': 3152,
#             'item2': 1082,
#             'item3': 3158,
#             'item4': 3108,
#             'item5': 3136,
#             'item6': 3340,
#             'killingSprees': 0,
#             'kills': 1,
#             'largestCriticalStrike': 0,
#             'largestKillingSpree': 0,
#             'largestMultiKill': 1,
#             'longestTimeSpentLiving': 444,
#             'magicDamageDealt': 79518,
#             'magicDamageDealtToChampions': 10911,
#             'magicalDamageTaken': 4189,
#             'neutralMinionsKilled': 0,
#             'neutralMinionsKilledEnemyJungle': 0,
#             'neutralMinionsKilledTeamJungle': 0,
#             'objectivePlayerScore': 0,
#             'participantId': 6,
#             'pentaKills': 0,
#             'perk0': 8230,
#             'perk0Var1': 8,
#             'perk0Var2': 0,
#             'perk0Var3': 0,
#             'perk1': 8275,
#             'perk1Var1': 6,
#             'perk1Var2': 0,
#             'perk1Var3': 0,
#             'perk2': 8210,
#             'perk2Var1': 0,
#             'perk2Var2': 0,
#             'perk2Var3': 0,
#             'perk3': 8236,
#             'perk3Var1': 24,
#             'perk3Var2': 0,
#             'perk3Var3': 0,
#             'perk4': 8321,
#             'perk4Var1': 4,
#             'perk4Var2': 0,
#             'perk4Var3': 0,
#             'perk5': 8347,
#             'perk5Var1': 0,
#             'perk5Var2': 0,
#             'perk5Var3': 0,
#             'perkPrimaryStyle': 8200,
#             'perkSubStyle': 8300,
#             'physicalDamageDealt': 10692,
#             'physicalDamageDealtToChampions': 221,
#             'physicalDamageTaken': 11478,
#             'playerScore0': 0,
#             'playerScore1': 0,
#             'playerScore2': 0,
#             'playerScore3': 0,
#             'playerScore4': 0,
#             'playerScore5': 0,
#             'playerScore6': 0,
#             'playerScore7': 0,
#             'playerScore8': 0,
#             'playerScore9': 0,
#             'quadraKills': 0,
#             'sightWardsBoughtInGame': 0,
#             'statPerk0': 5008,
#             'statPerk1': 5002,
#             'statPerk2': 5001,
#             'timeCCingOthers': 3,
#             'totalDamageDealt': 90894,
#             'totalDamageDealtToChampions': 11817,
#             'totalDamageTaken': 16625,
#             'totalHeal': 12071,
#             'totalMinionsKilled': 153,
#             'totalPlayerScore': 0,
#             'totalScoreRank': 0,
#             'totalTimeCrowdControlDealt': 90,
#             'totalUnitsHealed': 1,
#             'tripleKills': 0,
#             'trueDamageDealt': 684,
#             'trueDamageDealtToChampions': 684,
#             'trueDamageTaken': 957,
#             'turretKills': 0,
#             'unrealKills': 0,
#             'visionScore': 11,
#             'visionWardsBoughtInGame': 0,
#             'wardsKilled': 0,
#             'wardsPlaced': 7,
#             'win': False},
#   'teamId': 200,
#   'timeline': {'creepsPerMinDeltas': {'0-10': 7.1, '10-20': 6.1},
#                'csDiffPerMinDeltas': {'0-10': 2.1999999999999997,
#                                       '10-20': 0.5000000000000004},
#                'damageTakenDiffPerMinDeltas': {'0-10': 51.8,
#                                                '10-20': 296.19999999999993},
#                'damageTakenPerMinDeltas': {'0-10': 271.2,
#                                            '10-20': 859.6999999999999},
#                'goldPerMinDeltas': {'0-10': 259.1, '10-20': 352.70000000000005},
#                'lane': 'TOP',
#                'participantId': 6,
#                'role': 'SOLO',
#                'xpDiffPerMinDeltas': {'0-10': 22.799999999999983,
#                                       '10-20': -49.80000000000001},
#                'xpPerMinDeltas': {'0-10': 440.1, '10-20': 496}}},
#  {'championId': 72,
#   'participantId': 7,
#   'spell1Id': 11,
#   'spell2Id': 4,
#   'stats': {'assists': 1,
#             'champLevel': 11,
#             'combatPlayerScore': 0,
#             'damageDealtToObjectives': 17385,
#             'damageDealtToTurrets': 248,
#             'damageSelfMitigated': 20982,
#             'deaths': 6,
#             'doubleKills': 0,
#             'firstBloodAssist': False,
#             'firstBloodKill': False,
#             'firstInhibitorAssist': False,
#             'firstInhibitorKill': False,
#             'firstTowerAssist': False,
#             'firstTowerKill': False,
#             'goldEarned': 7556,
#             'goldSpent': 6575,
#             'inhibitorKills': 0,
#             'item0': 2031,
#             'item1': 1400,
#             'item2': 3111,
#             'item3': 3101,
#             'item4': 3044,
#             'item5': 1027,
#             'item6': 3340,
#             'killingSprees': 0,
#             'kills': 3,
#             'largestCriticalStrike': 0,
#             'largestKillingSpree': 0,
#             'largestMultiKill': 1,
#             'longestTimeSpentLiving': 541,
#             'magicDamageDealt': 19308,
#             'magicDamageDealtToChampions': 984,
#             'magicalDamageTaken': 5504,
#             'neutralMinionsKilled': 100,
#             'neutralMinionsKilledEnemyJungle': 4,
#             'neutralMinionsKilledTeamJungle': 70,
#             'objectivePlayerScore': 0,
#             'participantId': 7,
#             'pentaKills': 0,
#             'perk0': 8005,
#             'perk0Var1': 256,
#             'perk0Var2': 191,
#             'perk0Var3': 65,
#             'perk1': 9111,
#             'perk1Var1': 168,
#             'perk1Var2': 80,
#             'perk1Var3': 0,
#             'perk2': 9103,
#             'perk2Var1': 0,
#             'perk2Var2': 0,
#             'perk2Var3': 0,
#             'perk3': 8014,
#             'perk3Var1': 126,
#             'perk3Var2': 0,
#             'perk3Var3': 0,
#             'perk4': 8135,
#             'perk4Var1': 1257,
#             'perk4Var2': 3,
#             'perk4Var3': 0,
#             'perk5': 8138,
#             'perk5Var1': 4,
#             'perk5Var2': 0,
#             'perk5Var3': 0,
#             'perkPrimaryStyle': 8000,
#             'perkSubStyle': 8100,
#             'physicalDamageDealt': 73055,
#             'physicalDamageDealtToChampions': 4116,
#             'physicalDamageTaken': 14571,
#             'playerScore0': 0,
#             'playerScore1': 0,
#             'playerScore2': 0,
#             'playerScore3': 0,
#             'playerScore4': 0,
#             'playerScore5': 0,
#             'playerScore6': 0,
#             'playerScore7': 0,
#             'playerScore8': 0,
#             'playerScore9': 0,
#             'quadraKills': 0,
#             'sightWardsBoughtInGame': 0,
#             'statPerk0': 5008,
#             'statPerk1': 5008,
#             'statPerk2': 5002,
#             'timeCCingOthers': 27,
#             'totalDamageDealt': 102765,
#             'totalDamageDealtToChampions': 5844,
#             'totalDamageTaken': 21158,
#             'totalHeal': 6949,
#             'totalMinionsKilled': 8,
#             'totalPlayerScore': 0,
#             'totalScoreRank': 0,
#             'totalTimeCrowdControlDealt': 356,
#             'totalUnitsHealed': 1,
#             'tripleKills': 0,
#             'trueDamageDealt': 10402,
#             'trueDamageDealtToChampions': 744,
#             'trueDamageTaken': 1082,
#             'turretKills': 1,
#             'unrealKills': 0,
#             'visionScore': 14,
#             'visionWardsBoughtInGame': 0,
#             'wardsKilled': 0,
#             'wardsPlaced': 7,
#             'win': False},
#   'teamId': 200,
#   'timeline': {'creepsPerMinDeltas': {'0-10': 0.2, '10-20': 0.3},
#                'csDiffPerMinDeltas': {'0-10': 0.1,
#                                       '10-20': -0.9999999999999999},
#                'damageTakenDiffPerMinDeltas': {'0-10': 73.79999999999995,
#                                                '10-20': -83.19999999999999},
#                'damageTakenPerMinDeltas': {'0-10': 627.8, '10-20': 1048.3},
#                'goldPerMinDeltas': {'0-10': 281.8, '10-20': 339.2},
#                'lane': 'JUNGLE',
#                'participantId': 7,
#                'role': 'NONE',
#                'xpDiffPerMinDeltas': {'0-10': 28.19999999999999,
#                                       '10-20': -154.8},
#                'xpPerMinDeltas': {'0-10': 335.1, '10-20': 399.5}}},
#  {'championId': 37,
#   'highestAchievedSeasonTier': 'GOLD',
#   'participantId': 8,
#   'spell1Id': 3,
#   'spell2Id': 4,
#   'stats': {'assists': 1,
#             'champLevel': 10,
#             'combatPlayerScore': 0,
#             'damageDealtToObjectives': 0,
#             'damageDealtToTurrets': 0,
#             'damageSelfMitigated': 4267,
#             'deaths': 4,
#             'doubleKills': 0,
#             'firstBloodAssist': False,
#             'firstBloodKill': False,
#             'firstInhibitorAssist': False,
#             'firstInhibitorKill': False,
#             'firstTowerAssist': False,
#             'firstTowerKill': False,
#             'goldEarned': 4484,
#             'goldSpent': 3975,
#             'inhibitorKills': 0,
#             'item0': 3117,
#             'item1': 3114,
#             'item2': 2003,
#             'item3': 3092,
#             'item4': 2055,
#             'item5': 1028,
#             'item6': 3364,
#             'killingSprees': 0,
#             'kills': 0,
#             'largestCriticalStrike': 0,
#             'largestKillingSpree': 0,
#             'largestMultiKill': 0,
#             'longestTimeSpentLiving': 816,
#             'magicDamageDealt': 6180,
#             'magicDamageDealtToChampions': 4318,
#             'magicalDamageTaken': 4545,
#             'neutralMinionsKilled': 0,
#             'neutralMinionsKilledEnemyJungle': 0,
#             'neutralMinionsKilledTeamJungle': 0,
#             'objectivePlayerScore': 0,
#             'participantId': 8,
#             'pentaKills': 0,
#             'perk0': 8214,
#             'perk0Var1': 338,
#             'perk0Var2': 591,
#             'perk0Var3': 0,
#             'perk1': 8226,
#             'perk1Var1': 250,
#             'perk1Var2': 418,
#             'perk1Var3': 0,
#             'perk2': 8210,
#             'perk2Var1': 0,
#             'perk2Var2': 0,
#             'perk2Var3': 0,
#             'perk3': 8237,
#             'perk3Var1': 205,
#             'perk3Var2': 0,
#             'perk3Var3': 0,
#             'perk4': 8347,
#             'perk4Var1': 0,
#             'perk4Var2': 0,
#             'perk4Var3': 0,
#             'perk5': 8304,
#             'perk5Var1': 10,
#             'perk5Var2': 0,
#             'perk5Var3': 0,
#             'perkPrimaryStyle': 8200,
#             'perkSubStyle': 8300,
#             'physicalDamageDealt': 1723,
#             'physicalDamageDealtToChampions': 662,
#             'physicalDamageTaken': 4034,
#             'playerScore0': 0,
#             'playerScore1': 0,
#             'playerScore2': 0,
#             'playerScore3': 0,
#             'playerScore4': 0,
#             'playerScore5': 0,
#             'playerScore6': 0,
#             'playerScore7': 0,
#             'playerScore8': 0,
#             'playerScore9': 0,
#             'quadraKills': 0,
#             'sightWardsBoughtInGame': 0,
#             'statPerk0': 5007,
#             'statPerk1': 5008,
#             'statPerk2': 5001,
#             'timeCCingOthers': 11,
#             'totalDamageDealt': 7904,
#             'totalDamageDealtToChampions': 4981,
#             'totalDamageTaken': 9390,
#             'totalHeal': 4460,
#             'totalMinionsKilled': 3,
#             'totalPlayerScore': 0,
#             'totalScoreRank': 0,
#             'totalTimeCrowdControlDealt': 20,
#             'totalUnitsHealed': 5,
#             'tripleKills': 0,
#             'trueDamageDealt': 0,
#             'trueDamageDealtToChampions': 0,
#             'trueDamageTaken': 810,
#             'turretKills': 0,
#             'unrealKills': 0,
#             'visionScore': 17,
#             'visionWardsBoughtInGame': 1,
#             'wardsKilled': 2,
#             'wardsPlaced': 10,
#             'win': False},
#   'teamId': 200,
#   'timeline': {'creepsPerMinDeltas': {'0-10': 0, '10-20': 0.1},
#                'csDiffPerMinDeltas': {'0-10': -0.3500000000000001,
#                                       '10-20': -1.1000000000000005},
#                'damageTakenDiffPerMinDeltas': {'0-10': 59.20000000000002,
#                                                '10-20': 72.00000000000006},
#                'damageTakenPerMinDeltas': {'0-10': 162.9, '10-20': 558.3},
#                'goldPerMinDeltas': {'0-10': 127.8, '10-20': 188.4},
#                'lane': 'BOTTOM',
#                'participantId': 8,
#                'role': 'DUO_SUPPORT',
#                'xpDiffPerMinDeltas': {'0-10': -28.700000000000017,
#                                       '10-20': -136.09999999999997},
#                'xpPerMinDeltas': {'0-10': 275.6, '10-20': 267.9}}},
#  {'championId': 222,
#   'highestAchievedSeasonTier': 'GOLD',
#   'participantId': 9,
#   'spell1Id': 7,
#   'spell2Id': 4,
#   'stats': {'assists': 1,
#             'champLevel': 11,
#             'combatPlayerScore': 0,
#             'damageDealtToObjectives': 1714,
#             'damageDealtToTurrets': 1714,
#             'damageSelfMitigated': 5059,
#             'deaths': 4,
#             'doubleKills': 0,
#             'firstBloodAssist': False,
#             'firstBloodKill': False,
#             'firstInhibitorAssist': False,
#             'firstInhibitorKill': False,
#             'firstTowerAssist': False,
#             'firstTowerKill': False,
#             'goldEarned': 7445,
#             'goldSpent': 7350,
#             'inhibitorKills': 0,
#             'item0': 0,
#             'item1': 0,
#             'item2': 3031,
#             'item3': 3085,
#             'item4': 1055,
#             'item5': 3006,
#             'item6': 3340,
#             'killingSprees': 0,
#             'kills': 0,
#             'largestCriticalStrike': 363,
#             'largestKillingSpree': 0,
#             'largestMultiKill': 0,
#             'longestTimeSpentLiving': 827,
#             'magicDamageDealt': 642,
#             'magicDamageDealtToChampions': 437,
#             'magicalDamageTaken': 5833,
#             'neutralMinionsKilled': 4,
#             'neutralMinionsKilledEnemyJungle': 0,
#             'neutralMinionsKilledTeamJungle': 4,
#             'objectivePlayerScore': 0,
#             'participantId': 9,
#             'pentaKills': 0,
#             'perk0': 8008,
#             'perk0Var1': 1,
#             'perk0Var2': 40,
#             'perk0Var3': 0,
#             'perk1': 9111,
#             'perk1Var1': 38,
#             'perk1Var2': 20,
#             'perk1Var3': 0,
#             'perk2': 9103,
#             'perk2Var1': 0,
#             'perk2Var2': 0,
#             'perk2Var3': 0,
#             'perk3': 8014,
#             'perk3Var1': 65,
#             'perk3Var2': 0,
#             'perk3Var3': 0,
#             'perk4': 8304,
#             'perk4Var1': 10,
#             'perk4Var2': 0,
#             'perk4Var3': 0,
#             'perk5': 8345,
#             'perk5Var1': 4,
#             'perk5Var2': 0,
#             'perk5Var3': 0,
#             'perkPrimaryStyle': 8000,
#             'perkSubStyle': 8300,
#             'physicalDamageDealt': 101773,
#             'physicalDamageDealtToChampions': 7597,
#             'physicalDamageTaken': 6210,
#             'playerScore0': 0,
#             'playerScore1': 0,
#             'playerScore2': 0,
#             'playerScore3': 0,
#             'playerScore4': 0,
#             'playerScore5': 0,
#             'playerScore6': 0,
#             'playerScore7': 0,
#             'playerScore8': 0,
#             'playerScore9': 0,
#             'quadraKills': 0,
#             'sightWardsBoughtInGame': 0,
#             'statPerk0': 5005,
#             'statPerk1': 5008,
#             'statPerk2': 5001,
#             'timeCCingOthers': 11,
#             'totalDamageDealt': 103895,
#             'totalDamageDealtToChampions': 8034,
#             'totalDamageTaken': 12791,
#             'totalHeal': 1164,
#             'totalMinionsKilled': 185,
#             'totalPlayerScore': 0,
#             'totalScoreRank': 0,
#             'totalTimeCrowdControlDealt': 31,
#             'totalUnitsHealed': 2,
#             'tripleKills': 0,
#             'trueDamageDealt': 1480,
#             'trueDamageDealtToChampions': 0,
#             'trueDamageTaken': 746,
#             'turretKills': 0,
#             'unrealKills': 0,
#             'visionScore': 12,
#             'visionWardsBoughtInGame': 0,
#             'wardsKilled': 1,
#             'wardsPlaced': 7,
#             'win': False},
#   'teamId': 200,
#   'timeline': {'creepsPerMinDeltas': {'0-10': 7.1, '10-20': 8.6},
#                'csDiffPerMinDeltas': {'0-10': -0.3500000000000001,
#                                       '10-20': -1.1000000000000005},
#                'damageTakenDiffPerMinDeltas': {'0-10': 59.20000000000002,
#                                                '10-20': 72.00000000000006},
#                'damageTakenPerMinDeltas': {'0-10': 244.39999999999998,
#                                            '10-20': 640.1},
#                'goldPerMinDeltas': {'0-10': 243.8, '10-20': 326.5},
#                'lane': 'BOTTOM',
#                'participantId': 9,
#                'role': 'DUO_CARRY',
#                'xpDiffPerMinDeltas': {'0-10': -28.700000000000017,
#                                       '10-20': -136.09999999999997},
#                'xpPerMinDeltas': {'0-10': 299.1, '10-20': 368.70000000000005}}},
#  {'championId': 81,
#   'participantId': 10,
#   'spell1Id': 12,
#   'spell2Id': 4,
#   'stats': {'assists': 0,
#             'champLevel': 12,
#             'combatPlayerScore': 0,
#             'damageDealtToObjectives': 711,
#             'damageDealtToTurrets': 711,
#             'damageSelfMitigated': 4344,
#             'deaths': 6,
#             'doubleKills': 0,
#             'firstBloodAssist': False,
#             'firstBloodKill': False,
#             'firstInhibitorAssist': False,
#             'firstInhibitorKill': False,
#             'firstTowerAssist': False,
#             'firstTowerKill': False,
#             'goldEarned': 8031,
#             'goldSpent': 7125,
#             'inhibitorKills': 0,
#             'item0': 3070,
#             'item1': 3100,
#             'item2': 3020,
#             'item3': 2424,
#             'item4': 3802,
#             'item5': 0,
#             'item6': 3363,
#             'killingSprees': 0,
#             'kills': 3,
#             'largestCriticalStrike': 0,
#             'largestKillingSpree': 0,
#             'largestMultiKill': 1,
#             'longestTimeSpentLiving': 436,
#             'magicDamageDealt': 20127,
#             'magicDamageDealtToChampions': 5433,
#             'magicalDamageTaken': 6499,
#             'neutralMinionsKilled': 4,
#             'neutralMinionsKilledEnemyJungle': 0,
#             'neutralMinionsKilledTeamJungle': 4,
#             'objectivePlayerScore': 0,
#             'participantId': 10,
#             'pentaKills': 0,
#             'perk0': 8359,
#             'perk0Var1': 410,
#             'perk0Var2': 8,
#             'perk0Var3': 0,
#             'perk1': 8313,
#             'perk1Var1': 0,
#             'perk1Var2': 0,
#             'perk1Var3': 0,
#             'perk2': 8321,
#             'perk2Var1': 3,
#             'perk2Var2': 0,
#             'perk2Var3': 0,
#             'perk3': 8347,
#             'perk3Var1': 0,
#             'perk3Var2': 0,
#             'perk3Var3': 0,
#             'perk4': 8236,
#             'perk4Var1': 24,
#             'perk4Var2': 0,
#             'perk4Var3': 0,
#             'perk5': 8233,
#             'perk5Var1': 13,
#             'perk5Var2': 50,
#             'perk5Var3': 0,
#             'perkPrimaryStyle': 8300,
#             'perkSubStyle': 8200,
#             'physicalDamageDealt': 47686,
#             'physicalDamageDealtToChampions': 3036,
#             'physicalDamageTaken': 4314,
#             'playerScore0': 0,
#             'playerScore1': 0,
#             'playerScore2': 0,
#             'playerScore3': 0,
#             'playerScore4': 0,
#             'playerScore5': 0,
#             'playerScore6': 0,
#             'playerScore7': 0,
#             'playerScore8': 0,
#             'playerScore9': 0,
#             'quadraKills': 0,
#             'sightWardsBoughtInGame': 0,
#             'statPerk0': 5008,
#             'statPerk1': 5008,
#             'statPerk2': 5003,
#             'timeCCingOthers': 0,
#             'totalDamageDealt': 72703,
#             'totalDamageDealtToChampions': 8470,
#             'totalDamageTaken': 11403,
#             'totalHeal': 0,
#             'totalMinionsKilled': 138,
#             'totalPlayerScore': 0,
#             'totalScoreRank': 0,
#             'totalTimeCrowdControlDealt': 8,
#             'totalUnitsHealed': 0,
#             'tripleKills': 0,
#             'trueDamageDealt': 4890,
#             'trueDamageDealtToChampions': 0,
#             'trueDamageTaken': 588,
#             'turretKills': 0,
#             'unrealKills': 0,
#             'visionScore': 15,
#             'visionWardsBoughtInGame': 1,
#             'wardsKilled': 2,
#             'wardsPlaced': 9,
#             'win': False},
#   'teamId': 200,
#   'timeline': {'creepsPerMinDeltas': {'0-10': 6.2, '10-20': 5.7},
#                'csDiffPerMinDeltas': {'0-10': -0.20000000000000018,
#                                       '10-20': 0.2000000000000004},
#                'damageTakenDiffPerMinDeltas': {'0-10': 51.39999999999999,
#                                                '10-20': -21.099999999999994},
#                'damageTakenPerMinDeltas': {'0-10': 323.4, '10-20': 478.6},
#                'goldPerMinDeltas': {'0-10': 338.5, '10-20': 276.1},
#                'lane': 'MIDDLE',
#                'participantId': 10,
#                'role': 'SOLO',
#                'xpDiffPerMinDeltas': {'0-10': -17.49999999999997,
#                                       '10-20': -211.09999999999997},
#                'xpPerMinDeltas': {'0-10': 442.9, '10-20': 367.3}}}]

# %%
matchinfo_df = pd.read_csv(file)

# %%
matchinfo_df
# Out:
#      League  Year  Season    Type blueTeamTag  bResult  rResult redTeamTag  \
# 0     NALCS  2015  Spring  Season         TSM        1        0         C9
# 1     NALCS  2015  Spring  Season         CST        0        1        DIG
# 2     NALCS  2015  Spring  Season         WFX        1        0         GV
# 3     NALCS  2015  Spring  Season         TIP        0        1         TL
# 4     NALCS  2015  Spring  Season         CLG        1        0         T8
# ...     ...   ...     ...     ...         ...      ...      ...        ...
# 7615    TCL  2018  Spring  Season          YC        0        1        SUP
# 7616    TCL  2018  Spring  Season         GAL        0        1         DP
# 7617    OPL  2018  Spring  Season         SIN        0        1         DW
# 7618    OPL  2018  Spring  Season         LGC        1        0        TTC
# 7619    OPL  2018  Spring  Season         TTC        0        1        LGC
#
#       gamelength   blueTop  ... redTopChamp     redJungle redJungleChamp  \
# 0             40     Dyrus  ...        Gnar        Meteos          Elise
# 1             38      Cris  ...      Irelia       Crumbzz       JarvanIV
# 2             40   Flaresz  ...        Sion  Saintvicious         LeeSin
# 3             41      Rhux  ...        Gnar    IWDominate           Nunu
# 4             35     Benny  ...        Sion     Porpoise8         RekSai
# ...          ...       ...  ...         ...           ...            ...
# 7615          34    Elwind  ...     Chogath      Stomaged        XinZhao
# 7616          39      Rare  ...     Chogath         KaKAO          Ivern
# 7617          24  Praedyth  ...   Gangplank       Praelus        Evelynn
# 7618          35     Ceres  ...   Gangplank        Swathe       JarvanIV
# 7619          42   Papryze  ...        Ornn         Sybol       JarvanIV
#
#      redMiddle redMiddleChamp        redADC redADCChamp   redSupport  \
# 0          Hai           Fizz        Sneaky       Sivir  LemonNation
# 1     Shiphtur           Azir        CoreJJ       Corki      KiWiKiD
# 2        Keane           Azir           Cop       Corki   BunnyFuFuu
# 3        Fenix           Lulu         KEITH      KogMaw      Xpecial
# 4     Slooshi8           Lulu  Maplestreet8       Corki        Dodo8
# ...        ...            ...           ...         ...          ...
# 7615       GBM         Veigar       Zeitnot       Xayah   SnowFlower
# 7616    Lucete           Ryze      Ruvelius     Caitlyn       Japone
# 7617    Triple       Malzahar          k1ng      Ezreal      Cupcake
# 7618      Shok         Veigar           Low       Sivir      Tilting
# 7619    Claire       Malzahar          Raid       Vayne        Decoy
#
#      redSupportChamp                                            Address
# 0             Thresh  http://matchhistory.na.leagueoflegends.com/en/...
# 1              Annie  http://matchhistory.na.leagueoflegends.com/en/...
# 2              Janna  http://matchhistory.na.leagueoflegends.com/en/...
# 3              Janna  http://matchhistory.na.leagueoflegends.com/en/...
# 4              Annie  http://matchhistory.na.leagueoflegends.com/en/...
# ...              ...                                                ...
# 7615           Rakan  https://matchhistory.euw.leagueoflegends.com/e...
# 7616           Braum  https://matchhistory.euw.leagueoflegends.com/e...
# 7617           Taric  https://matchhistory.na.leagueoflegends.com/en...
# 7618           Janna  https://matchhistory.na.leagueoflegends.com/en...
# 7619           Braum  https://matchhistory.na.leagueoflegends.com/en...
#
# [7620 rows x 30 columns]

# %%
#avg blue team game length based on Team Name
bt_gl = matchinfo_df.groupby(["blueTeamTag"])
avg_bt_gl = pd.DataFrame(bt_gl["gamelength"].mean()) 
#avg red team game length based on Team Name
rt_gl = matchinfo_df.groupby(["redTeamTag"])
avg_rt_gl = pd.DataFrame(rt_gl["gamelength"].mean()) 
#rt_bt_gl = pd.merge(avg_rt_gl,avg_bt_gl, on = "redTeamTag")
#rt_bt_gl

# %%
matchinfo_df["Address"]
# Out:
# 0       http://matchhistory.na.leagueoflegends.com/en/...
# 1       http://matchhistory.na.leagueoflegends.com/en/...
# 2       http://matchhistory.na.leagueoflegends.com/en/...
# 3       http://matchhistory.na.leagueoflegends.com/en/...
# 4       http://matchhistory.na.leagueoflegends.com/en/...
#                               ...
# 7615    https://matchhistory.euw.leagueoflegends.com/e...
# 7616    https://matchhistory.euw.leagueoflegends.com/e...
# 7617    https://matchhistory.na.leagueoflegends.com/en...
# 7618    https://matchhistory.na.leagueoflegends.com/en...
# 7619    https://matchhistory.na.leagueoflegends.com/en...
# Name: Address, Length: 7620, dtype: object
